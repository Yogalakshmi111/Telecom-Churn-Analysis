# %% [markdown]
# ## <b> Orange S.A., formerly France Télécom S.A., is a French multinational telecommunications corporation. The Orange Telecom's Churn Dataset, consists of cleaned customer activity data (features), along with a churn label specifying whether a customer canceled the subscription.
#
# ## <b> Explore and analyze the data to discover key factors responsible for customer churn and come up with ways/recommendations to ensure customer retention. </b>

# %% [markdown]
# # Business Understanding Of A Telecom Industry Customer Churn:
#
# Customer churn is a big problem in any industry and one of the most important concerns for the Telecom industry. The effect on the revenues of the companies, because of this customer churns is huge, especially in the telecom field, that's why these companies are seeking to develop a predictive potential customer churn. In this highly competitive market, the telecommunications industry experiences an average of 15-25% annual churn rate, and it costs 5-10 times more to acquire a new customer than to retain an existing one, that's why customer retention has now become even more important than customer acquisition.
#
# Therefore, finding those factors that increase customer churn is important to take necessary actions to reduce this churn. The main goal of our project is to develop an understanding of the cause of customer churn which assists telecom operators to predict customers who are most likely subject to churn, and what to do to retain the most valuable customer.
#
# # Business Objective
# Maximize: Company's profit by retaining customer
#
# Minimize: Customer churn by identifying the key cause of the problem
#
# # The main objective of the project is to :
#
# Finding factors and cause those influence customers to churn.
#
# Retain churn customers by taking appropriate steps.
#
# Providing offers based on affecting factors.

# %%
import pandas as pd

# %%
churn = pd.read_csv('//content//drive//MyDrive//Copy of Telecom Churn.csv')

# %%
churn.head(50)
# Out:
#    State  Account length  ...  Customer service calls  Churn
# 0     KS             128  ...                       1  False
# 1     OH             107  ...                       1  False
# 2     NJ             137  ...                       0  False
# 3     OH              84  ...                       2  False
# 4     OK              75  ...                       3  False
# 5     AL             118  ...                       0  False
# 6     MA             121  ...                       3  False
# 7     MO             147  ...                       0  False
# 8     LA             117  ...                       1  False
# 9     WV             141  ...                       0  False
# 10    IN              65  ...                       4   True
# 11    RI              74  ...                       0  False
# 12    IA             168  ...                       1  False
# 13    MT              95  ...                       3  False
# ...

# %%
churn.tail()
# Out:
#      State  Account length  ...  Customer service calls  Churn
# 3328    AZ             192  ...                       2  False
# 3329    WV              68  ...                       3  False
# 3330    RI              28  ...                       2  False
# 3331    CT             184  ...                       2  False
# 3332    TN              74  ...                       0  False
#
# [5 rows x 20 columns]

# %%
churn.shape
# Out:
# (3333, 20)

# %% [markdown]
# In telecom churn data,we have 3333 rows and 20 columns

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %% [markdown]
# from the above info() we came to know that there was no null values in each column

# %%
churn.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                        bool
# dtype: object

# %%
churn.describe(include='all').T
# Out:
#                        count unique    top  freq  ...    25%    50%    75%    max
# State                   3333     51     WV   106  ...    NaN    NaN    NaN    NaN
# Account length          3333    NaN    NaN   NaN  ...     74    101    127    243
# Area code               3333    NaN    NaN   NaN  ...    408    415    510    510
# International plan      3333      2     No  3010  ...    NaN    NaN    NaN    NaN
# Voice mail plan         3333      2     No  2411  ...    NaN    NaN    NaN    NaN
# Number vmail messages   3333    NaN    NaN   NaN  ...      0      0     20     51
# Total day minutes       3333    NaN    NaN   NaN  ...  143.7  179.4  216.4  350.8
# Total day calls         3333    NaN    NaN   NaN  ...     87    101    114    165
# Total day charge        3333    NaN    NaN   NaN  ...  24.43   30.5  36.79  59.64
# Total eve minutes       3333    NaN    NaN   NaN  ...  166.6  201.4  235.3  363.7
# ...

# %% [markdown]
# There are 51 states iin this telecom churn dataset

# %%
print(churn.State.value_counts())
# Out:
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# OH     78
# OR     78
# VA     77
# WY     77
# CT     74
# VT     73
# ID     73
# MI     73
# UT     72
# TX     72
# IN     71
# MD     70
# KS     70
# MT     68
# NJ     68
# NC     68
# NV     66
# WA     66
# CO     66
# RI     65
# MS     65
# MA     65
# AZ     64
# FL     63
# MO     63
# NM     62
# ME     62
# ND     62
# DE     61
# OK     61
# NE     61
# SD     60
# SC     60
# KY     59
# IL     58
# NH     56
# AR     55
# DC     54
# GA     54
# HI     53
# TN     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: State, dtype: int64

# %%
churn.Churn.value_counts()
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
churn.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
churn =churn[['State','Account length', 'Area code', 'International plan',
       'Voice mail plan', 'Number vmail messages', 'Total day minutes',
       'Total day calls', 'Total day charge', 'Total eve minutes',
       'Total eve calls', 'Total eve charge', 'Total night minutes',
       'Total night calls', 'Total night charge', 'Total intl minutes',
       'Total intl calls', 'Total intl charge', 'Customer service calls',
       'Churn']]
churn.columns=['state', 'account_length', 'area_code', 'international_plan',
       'voice_mail_plan', 'number_vmail_messages', 'total_day_minutes',
       'total_day_calls', 'total_day_charge', 'total_eve_minutes',
       'total_eve_calls', 'total_eve_charge', 'total_night_minutes',
       'total_night_calls', 'total_night_charge', 'total_intl_minutes',
       'total_intl_calls', 'total_intl_charge', 'customer_service_calls',
       'churn']

# %%
churn.head(100)
# Out:
#    state  account_length  ...  customer_service_calls  churn
# 0     KS             128  ...                       1  False
# 1     OH             107  ...                       1  False
# 2     NJ             137  ...                       0  False
# 3     OH              84  ...                       2  False
# 4     OK              75  ...                       3  False
# ..   ...             ...  ...                     ...    ...
# 95    AK             104  ...                       1  False
# 96    MT              73  ...                       0  False
# 97    AZ              99  ...                       4  False
# 98    MS             120  ...                       1   True
# 99    ID              77  ...                       2   True
#
# [100 rows x 20 columns]

# %%
churn.isnull().sum()
# Out:
# state                     0
# account_length            0
# area_code                 0
# international_plan        0
# voice_mail_plan           0
# number_vmail_messages     0
# total_day_minutes         0
# total_day_calls           0
# total_day_charge          0
# total_eve_minutes         0
# total_eve_calls           0
# total_eve_charge          0
# total_night_minutes       0
# total_night_calls         0
# total_night_charge        0
# total_intl_minutes        0
# total_intl_calls          0
# total_intl_charge         0
# customer_service_calls    0
# churn                     0
# dtype: int64

# %%
len(churn[churn.duplicated()])
# Out:
# 0

# %% [markdown]
# 1.AS OF NOW THERE ARE 3333 ROWS AND 20 COLUMNS IN CHURN DATASET.
#
# 2.DATA TYPES=bool(1), float64(8), int64(8), object(3)
#
# 3.51 UNIQUE STATES.
#
# 4.THERE ARE NO MISSING OR NULL VALUE PRESENT.
#
# 5.THERE ARE NO DUPLICATED ENTRIES

# %% [markdown]
# # Exploratory Data Analysis Of The Data Set
#
# Analyzing the Dependent Variable 'CHURN'.

# %%
churn.nunique()
# Out:
# state                       51
# account_length             212
# area_code                    3
# international_plan           2
# voice_mail_plan              2
# number_vmail_messages       46
# total_day_minutes         1667
# total_day_calls            119
# total_day_charge          1667
# total_eve_minutes         1611
# total_eve_calls            123
# total_eve_charge          1440
# total_night_minutes       1591
# total_night_calls          120
# total_night_charge         933
# total_intl_minutes         162
# total_intl_calls            21
# total_intl_charge          162
# customer_service_calls      10
# churn                        2
# dtype: int64

# %%
churn['churn'].unique()
# Out:
# array([False,  True])

# %%
g=churn.churn.value_counts()
g
# Out:
# False    2850
# True      483
# Name: churn, dtype: int64

# %%
from matplotlib import pyplot as plt

# %%
explode=(0.1,0.1)
my_label=['not churned','churned']
plt.pie(g,autopct='%1.1f%%',startangle=90,shadow=True,explode=explode,labels=my_label)
plt.title('churn',loc='center')
plt.show()

# %%
import seaborn as sns
sns.countplot(x=churn.churn)

# %% [markdown]
# After analyzing the churn column, we had little to say like almost 15% of customers have churned. let's see what other features say to us and what relation we get after correlated with churn

# %% [markdown]
# # Analyzing State columns

# %%
churn['state'].nunique()
# Out:
# 51

# %%
churn['state'].unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
plt.figure(figsize=(18,8))
s=sns.countplot(x='state',hue='churn',data=churn)
plt.show()

# %%
state_unique=churn['state'].unique()
state_churn= churn.groupby('state')['churn'].mean()
plt.figure(figsize=(15,8))
plt.plot(state_unique,state_churn,marker='o',ms=12,lw=3,color='r',linestyle='-')
plt.title('average churn rate of each states',fontsize=20)
plt.xlabel('states',fontsize=20)
plt.ylabel('churn rate',fontsize=20)
plt.show()

# %%
x=churn.groupby('state')['churn'].mean()*100
x_max=x.sort_values(ascending=False).head(10)
print(x_max)
# Out:
# state
# CA    26.470588
# NJ    26.470588
# TX    25.000000
# MD    24.285714
# SC    23.333333
# MI    21.917808
# MS    21.538462
# NV    21.212121
# WA    21.212121
# ME    20.967742
# Name: churn, dtype: float64

# %%
colours=['#2F4F4F','#008080','#5F9EA0','#20B2AA','#66CDAA','#B0E0E6']
plt.figure(figsize=(10,6))
x_max=x.sort_values(ascending=False).head(6).plot.bar(color=colours,width=0.5)
plt.title('TOP 5 CHURNED STATES',fontsize=15)
plt.xlabel('STATES',fontsize=15)
plt.ylabel('PERCENTAGE',fontsize=15)
plt.show()

# %%
state_data= pd.crosstab(churn['state'],churn['churn'])
state_data['percentage_churn'] = state_data.apply(lambda x: x[1]*100/(x[0]+x[1]),axis=1)
state_data
# Out:
# churn  False  True  percentage_churn
# state
# AK        49     3          5.769231
# AL        72     8         10.000000
# AR        44    11         20.000000
# AZ        60     4          6.250000
# CA        25     9         26.470588
# CO        57     9         13.636364
# CT        62    12         16.216216
# DC        49     5          9.259259
# DE        52     9         14.754098
# FL        55     8         12.698413
# GA        46     8         14.814815
# HI        50     3          5.660377
# IA        41     3          6.818182
# ID        64     9         12.328767
# IL        53     5          8.620690
# IN        62     9         12.676056
# KS        57    13         18.571429
# KY        51     8         13.559322
# LA        47     4          7.843137
# MA        54    11         16.923077
# MD        53    17         24.285714
# ME        49    13         20.967742
# MI        57    16         21.917808
# MN        69    15         17.857143
# ...

# %%
state_data.sort_values(by=['percentage_churn'],ascending = False).head(10)
# Out:
# churn  False  True  percentage_churn
# state
# NJ        50    18         26.470588
# CA        25     9         26.470588
# TX        54    18         25.000000
# MD        53    17         24.285714
# SC        46    14         23.333333
# MI        57    16         21.917808
# MS        51    14         21.538462
# NV        52    14         21.212121
# WA        52    14         21.212121
# ME        49    13         20.967742

# %% [markdown]
# **There are 51 unique states**
# **Each states have different churn rate**
# **NJ, CA, TX, MD, SC, MI, MS, NV, WA, ME  are the top 10 churned  states,this may be due to low coverage of cellular network**

# %% [markdown]
# NOW ANALYZING THE AREA CODE WITH CHURN

# %%
area_churn = pd.crosstab (churn['area_code'],churn['churn'])
area_churn['percentage_churn'] = area_churn.apply(lambda x: x[1]*100/(x[0]+x[1]),axis=1)
area_churn
# Out:
# churn      False  True  percentage_churn
# area_code
# 408          716   122         14.558473
# 415         1419   236         14.259819
# 510          715   125         14.880952

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='area_code',hue='churn',data=churn)
plt.show()

# %% [markdown]
# IN THE ABOVE DATA THERE ARE ONLY THREE UNIQUE VALUES OF AREA CODE (408,415,510)
# AND THE RATE OF CHURN ARE ALMOST SAME. SO FROM THIS WE CAME TO KNOW THAT THERE IS NO IMPACT OF AREA CODE ON THE CHURN RATE

# %% [markdown]
# **ACCOUNT LENGHT VS CHURN**

# %%
acc_churn=pd.crosstab(churn['account_length'],churn['churn'])
acc_churn['percentage_churn']=acc_churn.apply(lambda x: x[1]*100/(x[0]+x[1]),axis = 1)
acc_churn
# Out:
# churn           False  True  percentage_churn
# account_length
# 1                   7     1              12.5
# 2                   0     1             100.0
# 3                   5     0               0.0
# 4                   1     0               0.0
# 5                   1     0               0.0
# ...               ...   ...               ...
# 221                 1     0               0.0
# 224                 1     1              50.0
# 225                 1     1              50.0
# 232                 1     0               0.0
# 243                 1     0               0.0
#
# [212 rows x 3 columns]

# %%
churned=churn[churn['churn']== bool(True)]

# %%
not_churned = churn[churn['churn']== bool(False)]

# %%
sns.displot(churn['account_length'],kind='hist',kde=True)

# %%
sns.displot(churn['account_length'],color='yellow',kind='hist',label='All',kde=True)
sns.displot(churned['account_length'],color='red',label='churned',kind='hist',kde='True')
sns.displot(not_churned['account_length'],color='green',kde=True,label='not churned')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.distplot(churn['account_length'],color='yellow',hist=True)
sns.distplot(churned['account_length'],color='red',hist=False)
sns.distplot(not_churned['account_length'],color='green',hist=False)
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# After analyzing various aspects of the "account length" column we didn't find any useful relation between account lenght and churn. let's see about other features which were the causes of churn

# %% [markdown]
# **INTERNATIONAL PLAN VS CHURN**

# %%
churn['international_plan'].value_counts()
# Out:
# No     3010
# Yes     323
# Name: international_plan, dtype: int64

# %%
intl_churn=pd.crosstab(churn['international_plan'],churn['churn'])
intl_churn['percentage_churn']=intl_churn.apply(lambda x:x[1]*100/(x[0]+x[1]),axis=1)
intl_churn
# Out:
# churn               False  True  percentage_churn
# international_plan
# No                   2664   346         11.495017
# Yes                   186   137         42.414861

# %%
explode=(0.1,0)
my_labels=('yes','no')
plt.figure(figsize=(10,7))
plt.pie(churn['international_plan'].value_counts(),startangle=90,autopct='%1.1f%%',labels=my_labels,explode=explode)
plt.title('international plan',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='international_plan',hue='churn',data=churn)
plt.show()

# %% [markdown]
# From the above data we get
#
# There are 3010 customers who didn't subscribed to international plan.
#
# There are 323 customers who have subscribed to international plan.
#
# Among those who have subscribed to international plan 42.41% of that people have churned.
#
# Whereas among those who didn't subscibed to international plan only 11.4 % of people churn.
#
# So basically the people who bought International plans are churning in big numbers.
#
# Probably because of connectivity issues or high call charge.

# %% [markdown]
# **VOICE MAIL PLAN VS CHURN**

# %%
voice_churn=pd.crosstab(churn['voice_mail_plan'],churn['churn'])
voice_churn['percentage_churn']=voice_churn.apply(lambda x:x[1]*100/(x[0]+x[1]),axis=1)
voice_churn
# Out:
# churn            False  True  percentage_churn
# voice_mail_plan
# No                2008   403         16.715056
# Yes                842    80          8.676790

# %%
my_labels1=('Yes','No')
explode=(0.03,0.03)
plt.figure(figsize=(10,7))
plt.pie(churn['voice_mail_plan'].value_counts(),autopct='%1.1f%%',startangle=90,labels=my_labels1,explode=explode,shadow=True)
plt.title('VOICE MAIL PLAN')
plt.show()

# %% [markdown]
# As we can see there is no clear relation between voice mail plan and churn.So let's move to the next voice mail feature i.e number of voice mail, let's see what it gives to us.

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='voice_mail_plan',hue='churn',data=churn)
plt.show()

# %% [markdown]
# **NUMBER OF VOICE MAIL MESSAGES VS CHURN**

# %%
churn['number_vmail_messages'].value_counts()
# Out:
# 0     2411
# 31      60
# 29      53
# 28      51
# 33      46
# 27      44
# 30      44
# 24      42
# 26      41
# 32      41
# 25      37
# 23      36
# 36      34
# 35      32
# 22      32
# 39      30
# 37      29
# 34      29
# 21      28
# 38      25
# 20      22
# 19      19
# 40      16
# 42      15
# 17      14
# 41      13
# 16      13
# 43       9
# 15       9
# 18       7
# 44       7
# 14       7
# 45       6
# 12       6
# 46       4
# 13       4
# 47       3
# 8        2
# 48       2
# 50       2
# 9        2
# 11       2
# 49       1
# 10       1
# 4        1
# 51       1
# Name: number_vmail_messages, dtype: int64

# %%
plt.figure(figsize=(10,7))
sns.distplot(churn['number_vmail_messages'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,7))
sns.distplot(churn['number_vmail_messages'])
sns.distplot(churned['number_vmail_messages'],hist=False,color='red')
sns.distplot(not_churned['number_vmail_messages'],hist=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
churn.boxplot(column='number_vmail_messages',by='churn',figsize=(10,8))
plt.suptitle('number_vmail_messages',fontsize=15,fontweight='bold')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# After analyzing the above voice mail feature data we get an insight that when there are more than 20 voice-mail messages then there is a churn
#
# For that, we need to improve the voice mail quality.

# %% [markdown]
# # Customer Care Calls VS Churn

# %%
customer_ser_churn=pd.crosstab(churn['customer_service_calls'],churn['churn'])
customer_ser_churn['percentage_churn']=customer_ser_churn.apply(lambda x: x[1]*100/(x[0]+x[1]),axis=1)
customer_ser_churn
# Out:
# churn                   False  True  percentage_churn
# customer_service_calls
# 0                         605    92         13.199426
# 1                        1059   122         10.330229
# 2                         672    87         11.462451
# 3                         385    44         10.256410
# 4                          90    76         45.783133
# 5                          26    40         60.606061
# 6                           8    14         63.636364
# 7                           4     5         55.555556
# 8                           1     1         50.000000
# 9                           0     2        100.000000

# %%
customer_ser_churn.shape
# Out:
# (10, 3)

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='customer_service_calls',hue='churn',data=churn)
plt.show()

# %% [markdown]
# # **Bad customer service is when a customer feels their expectations were not met.**
#
# ***It is observed from the above analysis that, mostly because of bad customer service, people tend to leave the operator.***
#
# ***The above data indicating that those customers who called the service center 4 times or above those customer churn percentage is more than 45%,***
#
# ***And customers who have called once also have a high churn rate indicating their issue was not solved in the first attempt.***
#
# ***So operator should work to improve the service call.***

# %% [markdown]
# # Analyzing day_eve_night_intl calls,day_eve_night_intl minutes, day_eve_night_intl charges charge.
#
# ***As these data sets are numerical data type, so for analysing with the 'churn' which is a catagorical data set, We are using mean.***

# %%
# total_day_calls
print(churn.groupby(['churn']) ['total_day_calls'].mean())
# Out:
# churn
# False    100.283158
# True     101.335404
# Name: total_day_calls, dtype: float64

# %%
#total_day_minutes
print(churn.groupby(['churn'])['total_day_minutes'].mean())
# Out:
# churn
# False    175.175754
# True     206.914079
# Name: total_day_minutes, dtype: float64

# %%
#total_day_charges
print(churn.groupby(['churn'])['total_day_charge'].mean())
# Out:
# churn
# False    29.780421
# True     35.175921
# Name: total_day_charge, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='total_day_minutes',y='total_day_charge',hue='churn',data=churn,palette='hls')
plt.show()

# %%
#total_eve_calls
print(churn.groupby(['churn'])['total_eve_calls'].mean())
# Out:
# churn
# False    100.038596
# True     100.561077
# Name: total_eve_calls, dtype: float64

# %%
#total_eve_minutes
print(churn.groupby(['churn'])['total_eve_minutes'].mean())
# Out:
# churn
# False    199.043298
# True     212.410145
# Name: total_eve_minutes, dtype: float64

# %%
#total_eve_charge
print(churn.groupby(['churn'])['total_eve_charge'].mean())
# Out:
# churn
# False    16.918909
# True     18.054969
# Name: total_eve_charge, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='total_eve_minutes',y='total_eve_charge',hue='churn',data=churn,palette='hls')
plt.show()

# %%
#total_night_calls
print(churn.groupby(['churn'])['total_night_calls'].mean())
# Out:
# churn
# False    100.058246
# True     100.399586
# Name: total_night_calls, dtype: float64

# %%
#total_night_minutes
print(churn.groupby(['churn'])['total_night_minutes'].mean())
# Out:
# churn
# False    200.133193
# True     205.231677
# Name: total_night_minutes, dtype: float64

# %%
#total_night_charge
print(churn.groupby(['churn'])['total_night_charge'].mean())
# Out:
# churn
# False    9.006074
# True     9.235528
# Name: total_night_charge, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='total_night_minutes',y='total_night_charge',hue='churn',data=churn,palette='hls')
plt.show()

# %%
#total_intl_calls
print(churn.groupby(['churn'])['total_intl_calls'].mean())
# Out:
# churn
# False    4.532982
# True     4.163561
# Name: total_intl_calls, dtype: float64

# %%
#total_intl_minutes
print(churn.groupby(['churn'])['total_intl_minutes'].mean())
# Out:
# churn
# False    10.158877
# True     10.700000
# Name: total_intl_minutes, dtype: float64

# %%
#total_intl_charge
print(churn.groupby(['churn'])['total_intl_charge'].mean())
# Out:
# churn
# False    2.743404
# True     2.889545
# Name: total_intl_charge, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='total_intl_minutes',y='total_intl_charge',hue='churn',data=churn,palette='hls')
plt.show()

# %%
day_charge_per_min=churn['total_day_charge'].mean()/churn['total_day_minutes'].mean()
eve_charge_per_min=churn['total_eve_charge'].mean()/churn['total_eve_minutes'].mean()
night_charge_per_min=churn['total_night_charge'].mean()/churn['total_night_minutes'].mean()
intl_charge_per_min=churn['total_intl_charge'].mean()/churn['total_intl_minutes'].mean()

# %%
print([day_charge_per_min,eve_charge_per_min,night_charge_per_min,intl_charge_per_min])
# Out:
# [0.1700030073913066, 0.08500104871485774, 0.04500041448440013, 0.2700500279887098]

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=['day','eve','night','intl'],y=[day_charge_per_min,eve_charge_per_min,night_charge_per_min,intl_charge_per_min])
plt.show()

# %% [markdown]
# **After analyzing the above dataset, we have noticed that total day/night/eve minutes/call/charges are not the cause for churn rate. But international call charges per minute are high as compare to others. It's an obvious thing, but that may be a cause for international plan customers to churn out.**

# %% [markdown]
# # UNIVARIATE ANALYSIS
# In Univariate Analysis we analyze data over a single column from the numerical dataset, for this we use 3 types of plot which are box plot, dis plot.

# %%
indi_col_analysis=churn.select_dtypes(exclude=['object','bool'])
for column in indi_col_analysis:
  plt.figure(figsize=(18,1))
  sns.boxplot(data=indi_col_analysis,x=column)
  plt.show()

# %%
for column in indi_col_analysis:
  plt.figure(figsize=(17,1))
  sns.displot(x=column,data=indi_col_analysis)
  plt.show()

# %% [markdown]
# # BIVARIATE ANALYSIS
# In Bivariate Analysis we analyze data by taking two columns into consideration from a dataset, here we only take numerical data type column, for this visualization we use scatter plot

# %%
df1=churn.describe().columns
for column in df1:
  ax=plt.figure(figsize=(17,3))
  feature=churn[column]
  label=churn['churn']
  correlation=feature.corr(label)
  plt.scatter(x=feature,y=label)
  plt.xlabel(column)
  plt.ylabel('churn')
  plt.show()

# %% [markdown]
# # MULTIVARIATE ANALYSIS
# In Multivariate Analysis we analyze data by taking more than two columns into consideration from a dataset,for this we using correlation plot,correlation matrix, correletaion heatmap.

# %%
#CORRELATION PLOT
plt.figure(figsize=(17,10))
churn.corr()['churn'].sort_values(ascending=False).plot(kind='bar',color=['red','green','blue','yellow','indigo','orange','brown','pink'])
plt.show()

# %%
#CORRELATION MATRIX
plt.figure(figsize=(19,10))
correlation=churn.corr()
sns.heatmap(data=correlation,cmap='coolwarm',annot=True)
plt.show()

# %%
#CORRELATION HEATMAP
plt.figure(figsize=(19,8))
sns.heatmap(data=correlation,annot=False,cmap='Paired')
plt.show()

# %% [markdown]
# # CONCLUSION:
#
# After performing exploratory data analysis on the data set, this is what we have incurred from data:
#
# There are some states where the churn rate is high as compared to others may be due to low network coverage.
#
# Area code and Account length did not play any role regarding the churn rate so,it's redundant data columns.
#
# In the International plan those customers who have subscribed to this plan are churned more and also the international calling charges are also high so the customer who subscribed dissatisfied with network issues and high call charge.
#
# IN the voice mail section when there are more than 20 voice-mail messages then there was a churn so it's basically means that the quality of voice mail is not good.
#
# Total day calls, total day call minutes, Total day charge, Total eve calls, Total eve minutes, Total eve charge, Total night calls, Total night minutes, Total night charge, these columns didn't play any role regarding the churn rate.
#
# In international calls data shows that the churn rate of those customers is high, those who take the international plan so it means that in international call charges are high also there is a call drop or network issue.
#
# In Customer service call data shows us,it is observed from the above analysis that, mostly because of bad customer service, people tend to leave the operator.
# The above data indicating that those customers who called the service center 4 times or above those customer churn percentage is more than 45%, And customers who have called once also have a high churn rate indicating their issue was not solved in the first attempt.
#
#
#
# # RECOMENDATIONS:
#
# Improve network coverage churned state
#
# In International plan,OPerator should provide some discount plans to the customer and improve the quality of the International calls.
#
# Improve the voice mail quality and  take the feedback from the customer regularly.
#
# Improve the service of call center and take frequently feedback from the customer regarding their issue and try to solve it as soon as possible.
